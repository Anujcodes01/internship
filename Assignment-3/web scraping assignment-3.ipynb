# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Let's import all required Libraries
import selenium #library that is used to work with selenium
from selenium import webdriver #importing webdriver module from selenium to open automated chrome window
import pandas as pd #to create DataFrame
import numpy as np
from selenium.webdriver.common.by import By #importing inbuilt class By
import warnings #to ignore any sort of warning
warnings.filterwarnings ("ignore")
import time #use to stop search engine for few seconds
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import WebDriverException
import time

# %% [markdown]
# ### 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.amazon.in/'
driver.get(url)

# %%
def search():
    search_tag = driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
    search_input = str(input("type what you want to search -->"))
    search_tag.send_keys(search_input)
    time.sleep(2)
    search_click = driver.find_element(By.ID,'nav-search-submit-button')
    search_click.click()

# %%
search()
# Out:
# type what you want to search -->guitar

# %% [markdown]
# ### 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and  “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# Create empty lists to store the required data
Brand=[]
product=[]
price=[]
Expected_Delivery=[]
availability_list = []
Product_url=[]


# Define the start and end page numbers
start = 0
end = 3
for page in range(start,end):
     # Find all the elements for Brand tag and append their text to the Brand list
    Brand_tag = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in Brand_tag:
        
        if i.text is None: #if any of the details are missing for any of the product then replace it by “-“.
            Brand.append('-')
        else:
            Brand.append(i.text.split(" ")[0])
     
    
    # Find all the elements for product tag and append their text to the Brand list
    product_tag = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in product_tag:
        
        if i.text is None: #if any of the details are missing for any of the product then replace it by “-“.
            product.append('-')
        else:
            product.append(i.text)
            
            
    price_tag = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in price_tag:
        if i.text is None:
            price.append('-')
        else:
            price.append(i.text)
            
    Product_url_tag = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in Product_url_tag:
        if i.text is None:
            Product_url.append('-')
        else:
            url = i.get_attribute("href")
            Product_url.append(url)
    Expected_Delivery_tag = driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
    for i in Expected_Delivery_tag:
        if i.text is None:
            Expected_Delivery.append('-')
        else:
            Expected_Delivery.append(i.text)
            
        # Initialize an empty list to store the availability of each product
    

    # Loop through each product URL
    for url in Product_url:
        
        driver.get(url)
        # Find all the elements that match the given XPath
        availability_elements = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        # Loop through each availability element and add its text to the list
        for element in availability_elements:
            availability_list.append(element.text)
            if len(availability_list)==10:
                
                break
        returns = driver.find_elements(By.XPATH,'//a[@class="a-section a-spacing-none icon-content"]')
        # Loop through each availability element and add its text to the list
        for element in returns:
            Return.append(element.text.split()[2])
            if len(Return)==10:
            
                break


    

# Brand=Brand[:180]
product=product[:180]
price=price[:180]
Expected_Delivery=Expected_Delivery[:180]
availability_list = availability_list[:180]
Product_url=Product_url[:180]

# %%
Brand=Brand[:60]
product=product[:60]
price=price[:60]
Expected_Delivery=Expected_Delivery[:60]
availability_list = availability_list[:60]
Product_url=Product_url[:60]


# Create a dictionary with the data
data = {
    'Brand': Brand,
    'Product': product,
    'Price': price,
    'Expected Delivery': Expected_Delivery,
    'Availability': availability_list,
    'Product URL': Product_url,
    
}

# Create a dataframe from the dictionary

df = pd.DataFrame(data)

# Display the dataframe
df
# Out:
#         Brand                                            Product   Price  \
# 0     Kadence  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...   8,499
# 1     Kadence  Kadence Frontier guitar with Online Guitar lea...   7,029
# 2   Blueberry  Blueberry VIP 301, 30 Inch Acoustic Guitar Kit...   6,899
# 3   Blueberry  Blueberry VIP 300, 30 Inch Acoustic Guitar Kit...   4,444
# 4      Juârez  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   3,125
# 5      Intern  Intern INT-38C Right hand Acoustic Guitar Kit,...   2,655
# 6      Yamaha  Yamaha F280 Acoustic Rosewood Guitar (Natural,...   1,999
# 7      Juarez  Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...   2,399
# 8      Juarez  Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...   7,200
# 9      Intern          Intern INT-38C Acoustic Guitar Kit (Blue)  11,999
# 10     Henrix  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...   1,999
# 11     Intern  Intern 38C Wooden Acoustic Steel-String Guitar...   1,999
# ...

# %%
Return = []
# Loop through each product URL
for url in Product_url:
    if len(Product_url)>60:
        try:
            driver.get(url)

returns = driver.find_elements(By.XPATH,'//a[@class="a-section a-spacing-none icon-content"]')
# Loop through each availability element and add its text to the list
for element in returns:
    Return.append(element.text.split()[2])
        except WebDriverException as e:
            print(f"Encountered a WebDriverException: {e}")
        # take appropriate action based on the specific error message 
    else:
        break

# %%
# Out:
# []

# %% [markdown]
# ### 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://images.google.com'
driver.get(url)

# %%
# First, we scroll down the webpage 20 times to load more images
for _ in range(20):
    driver.execute_script('window.scrollBy(0, -window.innerHeight)')

# Find all the image elements on the webpage
images = driver.find_elements(By.XPATH, '//img[@class="rg_i Q4LuWd"]')

# Create an empty list to store image URLs
img_urls = []

# Loop through each image element and extract the source URL
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)

# Create empty lists to store image data and URLs of the downloaded images
img_data = []
downloaded_img_urls = []

# Loop through the first 10 URLs in the img_urls list, download the images, and save them to the specified folder
for i in range(len(img_urls)):
    # Only download the first 10 images
    if i > 10:
        break

    # Print a message indicating the progress of the download process
    print("Downloading {0} of {1} images".format(i+1, 10))

    # Send an HTTP request to the image URL and get the response object
    response = requests.get(img_urls[i])

    # Open a new file in binary write mode and save the response content to it
    file = open(r"C:\Users\ASUS\Documents\assign image" + str(i) + '.jpg', 'wb')
    file.write(response.content)

    # Add the downloaded image URL to the downloaded_img_urls list
    downloaded_img_urls.append(img_urls[i])

# Print a message indicating the completion of the download process
print("Download completed successfully!")

# %% [markdown]
# ### 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.flipkart.com'
driver.get(url)

# %%
def search():
    # Find the search bar element and take user input for search term
    Search_tag=driver.find_element(By.XPATH,'//input[@class="_3704LK"]')
    search_input=str(input('Type here and I will get you there -->  '))
    # Enter the search term in the search bar
    Search_tag.send_keys(search_input)
    time.sleep(5)
    # Find the search button and click it
    search=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
    search.click()
    # Scroll to the end of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)#sleep_between_interactions

# %%
search()
# Out:
# Type here and I will get you there -->  pixel 4A

# %%
# Define lists to store the scraped details
Brand = []
Product = []
Color = []
RAM = []
Storage = []
Primary_Camera = []
Secondary_Camera = []
Display_Size = []
Battery_Capacity = []
Price = []
Product_url = []

# Define the URL of the website to scrape
url = 'https://www.flipkart.com/'



driver.get(url)
time.sleep(2)

search()

# Find all the product containers on the page and iterate over them
product_containers = driver.find_elements(By.XPATH, '//div[@class="_2kHMtA"]')
for container in product_containers:
    
    # Find the brand name and append it to the Brand list
    try:
        brand = container.find_element(By.XPATH, './/div[@class="_4rR01T"]')
        Brand.append(brand.text.split(' ')[0])
    except:
        Brand.append('-')
    
    # Find the product name and append it to the Product list
    try:
        product = container.find_element(By.XPATH, './/div[@class="_4rR01T"]')
        Product.append(product.text)
    except:
        Product.append('-')
    
    # Find the color and append it to the Color list
    try:
        color = container.find_element(By.XPATH, './/div[@class="_4rR01T"]')
        Color.append(color.text.split(' ')[-4:-2])
    except:
        Color.append('-')
    
    # Find the RAM and append it to the RAM list
    try:
        ram = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[1]')
        RAM.append(ram.text.split()[0:3])
    except:
        RAM.append('-')
    
    # Find the storage and append it to the Storage list
    try:
        storage = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[1]')
        Storage.append(storage.text.split()[4:])
    except:
        Storage.append('-')
    
    # Find the primary camera and append it to the Primary_Camera list
    try:
        primary_camera = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[3]')
        Primary_Camera.append(primary_camera.text)
    except:
        Primary_Camera.append('-')
    
    # Find the secondary camera and append it to the Secondary_Camera list
    try:
        secondary_camera = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[4]')
        Secondary_Camera.append(secondary_camera.text)
    except:
        Secondary_Camera.append('-')
    
    # Find the display size and append it to the Display_Size list
    try:
        display_size = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[2]')
        Display_Size.append(display_size.text)
    except:
        Display_Size.append('-')
    
    # Find the battery capacity and append it to the Battery_Capacity list
    try:
        battery_capacity = container.find_element(By.XPATH, './/ul[@class="_1xgFaf"]/li[5]')
        Battery_Capacity.append(battery_capacity.text)
    except:
        Battery_Capacity.append('-')
        
    # Find the Price and append it to the Price list
    try: 
        price = container.find_element(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
        Price.append(price.text)
    except:
        Price.append('-')
        
    # Find the Product_url and append it to the Product_url list
    product_url = container.find_element(By.XPATH,'//a[@class="_1fQZEK"]')
    try:
        urrl = product_url.get_attribute('href')
        Product_url.append(urrl)
    except:
        Product_url.append('-')
# create data frame 
data_dict = {
'Brand': Brand,
'Product': Product,
'Color': Color,
'RAM': RAM,
'Storage': Storage,
'Primary Camera': Primary_Camera,
'Secondary Camera': Secondary_Camera,
'Display Size': Display_Size,
'Battery Capacity': Battery_Capacity,
'Price': Price,
'Product URL': Product_url
}

data_dict = pd.DataFrame(data_dict)
# Out:
# Type here and I will get you there -->  OnePlus Nord

# %%
data_dict.head(10)
# Out:
#      Brand                                         Product             Color  \
# 0  OnePlus   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)    [(Blue, Tide,]
# 1  OnePlus   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)    [(Blue, Tide,]
# 2  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)   [(Black, Dusk,]
# 3  OnePlus        OnePlus Nord 2T 5G (Gray Shadow, 128 GB)  [(Gray, Shadow,]
# 4  OnePlus           OnePlus Nord 2T 5G (Jade Fog, 256 GB)     [(Jade, Fog,]
# 5  OnePlus         OnePlus Nord CE 5G (Silver Ray, 256 GB)   [(Silver, Ray,]
# 6  OnePlus           OnePlus Nord 2T 5G (Jade Fog, 128 GB)     [(Jade, Fog,]
# 7  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)   [(Black, Dusk,]
# 8  OnePlus           OnePlus Nord 2T 5G (Jade Fog, 128 GB)     [(Jade, Fog,]
# 9  OnePlus         OnePlus Nord 2 5G (Gray Sierra, 128 GB)  [(Gray, Sierra,]
#
#              RAM         Storage    Primary Camera  Secondary Camera  \
# ...

# %%
data_dict.to_csv('smartphone.csv')

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.google.com/maps'
driver.get(url)

# %%
# Define a function called "search" that performs a Google search
def search():
    # Find the search box element on the Google homepage using XPath
    search_tag = driver.find_element(By.XPATH, '//input[@class="tactile-searchbox-input"]')

    # Get the search query from the user
    search_input = str(input("type what you want to search -->"))

    # Enter the search query into the search box
    search_tag.send_keys(search_input)

    # Wait for 2 seconds to allow the page to load the search results
    time.sleep(2)

    # Find the "Google Search" button on the page using XPath and click it
    search_click = driver.find_element(By.XPATH, '//div[@class="pzfvzf"]')
    search_click.click()

# %%
search()
# Out:
# type what you want to search -->goa

# %%
import re

link = "https://www.google.com/maps/place/Goa/@15.3487596,73.3471976,9z/data=!3m1!4b1!4m6!3m5!1s0x3bbfba106336b741:0xeaf887ff62f34092!8m2!3d15.2993265!4d74.123996!16zL20vMDFjMW5t"

# Use regular expressions to extract latitude and longitude from the link
pattern = r"@(-?\d+\.\d+),(-?\d+\.\d+)"
matches = re.findall(pattern, link)

# Print the latitude and longitude values
if matches:
    latitude, longitude = matches[0]
    print("Latitude:", latitude)
    print("Longitude:", longitude)
else:
    print("No latitude and longitude values found in the link.")
# Out:
# Latitude: 15.3487596
# Longitude: 73.3471976

# %% [markdown]
# ### 6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.digit.in/'
driver.get(url)

# %%
# Get laptop names
lap_name = []
lap_tag = driver.find_elements(By.XPATH, '//div[@class="left_side"]')
for i in lap_tag:
    lap_name.append(i.text.replace('\n',''))
lap_name = lap_name[:10]


    

# Get laptop specifications
specifications =[]
secps_tag = driver.find_elements(By.XPATH, '//div[@class="Spcs-details"]')
for i in secps_tag:
    specifications.append(i.text.split('\n'))
specifications


    

# Get laptop descriptions
description = []
des = driver.find_elements(By.XPATH, '//div[@class="tptn-prod-desc"]')
for i in des:
    description.append(i.text)

# Create dataframe
data = {'Name': lap_name,'Specifications':specifications , 'Description': description,}
df = pd.DataFrame(data)

# Print dataframe
df
# Out:
#                                                Name  \
# 0                            1.MSI Titan GT77-12UHS
# 1                                 2.Lenovo Legion 7
# 2                                3.Alienware X17 R2
# 3           4.Acer Predator Triton 500 SE PT516-52s
# 4                         5.Omen By HP (16-B1371TX)
# 5               6.Acer Predator Helios 300 AN515-45
# 6                      7.MSI Delta 15 (A5EFK-083IN)
# 7                         8.Omen By HP (16-C0141AX)
# 8               9.Lenovo Legion 5i Pro (82RF00MGIN)
# 9  10.Alienware M15 R5 Ryzen Edition Icc-C780001win
#
#                                       Specifications  \
# 0  [MORE SPECIFICATIONS, Processor : 12th Gen Int...
# 1  [MORE SPECIFICATIONS, Processor : 12th Gen Int...
# 2  [MORE SPECIFICATIONS, Processor : 12th Gen Int...
# 3  [MORE SPECIFICATIONS, Processor : 12th Gen Int...
# 4  [MORE SPECIFICATIONS, Processor : 12th Gen Int...
# 5  [MORE SPECIFICATIONS, Processor : AMD Ryzen 9-...
# ...

# %% [markdown]
# ### 7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.forbes.com/billionaires/'
driver.get(url)

# %%
Name =[]
Age =[]
Source =[]
Industry =[]
Citizenship=[]
Net_worth=[]
Rank=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="Table_dataCell__2QCve"]')
for x in name_tag:
    Name.append(x.text)
    
Name= Name[0:801:4]
age_tag=driver.find_elements(By.XPATH,'//div[@class="Table_dataCell__2QCve"]')
for x in name_tag:
    Age.append(x.text)
Age = Age[1:801:4]
import time
Sources=[]
# scraping the data of source of income of the billionaires
sour_tag = driver.find_elements(By.CLASS_NAME,"Table_dataCell__2QCve")
for sour in sour_tag:
    Sources.append(sour.text)
time.sleep(1)

Industrys=[]
# scraping data of industry of the billionaires
ind_tag = driver.find_elements(By.CLASS_NAME,"Table_dataCell__2QCve")
for ind in ind_tag:
    Industrys.append(ind.text)
time.sleep(1)
industry = (Industrys[4:1201:6])
sources = Sources[5:1201:6]
citizenship = driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in citizenship:
    Citizenship.append(i.text)
Citizenship= Citizenship[4:1401:7]

networth = driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in networth:
    Net_worth.append(i.text)
Net_worth= Net_worth[2:1401:7]
rank = driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in rank:
    Rank.append(i.text)
Rank= Rank[0:1401:7]


# Define the data
data = {
    "Rank":Rank,
    "Name": Name,
    "Net worth": Net_worth,
    "Age": Age,
    "Citizenship": Citizenship,
    "Source": sources,
    "Industry": industry
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Rank                      Name Net worth Age    Citizenship  \
# 0      1  Bernard Arnault & family    $211 B  74         France
# 1      2                 Elon Musk    $180 B  51  United States
# 2      3                Jeff Bezos    $114 B  59  United States
# 3      4             Larry Ellison    $107 B  78  United States
# 4      5            Warren Buffett    $106 B  92  United States
# ..   ...                       ...       ...  ..            ...
# 195  195               Jin Baofang    $9.6 B  70          China
# 196  195        Luo Liguo & family    $9.6 B  67          China
# 197  195              Marijke Mars    $9.6 B  58  United States
# 198  195               Pamela Mars    $9.6 B  62  United States
# 199  195              Valerie Mars    $9.6 B  64  United States
#
#                     Source            Industry
# 0         Fashion & Retail                LVMH
# 1               Automotive       Tesla, SpaceX
# 2               Technology              Amazon
# ...

# %% [markdown]
# ### 8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
import pandas as pd

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://youtube.com/shorts/hQSevuaOf6M?feature=share'
driver.get(url)

# %%
youtube = driver.find_element(By.XPATH,
                              '/html/body/ytd-app/div[1]/ytd-page-manager/ytd-shorts/div[2]/div[2]/ytd-reel-video-renderer[1]/div[3]/ytd-reel-player-overlay-renderer/div[2]/div[4]/ytd-button-renderer/yt-button-shape/label/button/yt-touch-feedback-shape/div/div[2]')
youtube.click()

# %%
# 1000 times we scroll down by 10000 in order to generate more comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
# It is taking too much time and my pc is slow that's why i only fetched 20 rows 

try:
    comments=[]
    comment=driver.find_elements(By.ID,'content-text')
    for x in comment:
        comments.append(x.text)

    comments = comments[:20]
    # Extract the time when each comment was posted and store in a list
    time=[]
    tm=driver.find_elements(By.XPATH,'//a[@dir="auto"]')
    for x in tm:
        time.append(x.text)
    time = time[3:23]
    # Extract the number of upvotes for each comment and store in a list
   
    upvote=[]
    vote=driver.find_elements(By.ID,'vote-count-middle')
    for x in vote:
        upvote.append(x.text)
    upvote = upvote[:20]

    
except WebDriverException as e:
    # If a WebDriverException occurs, print an error message that includes the type and message of the exception
    print("WebDriverException occurred: {0}".format(e))

# %%
df = pd.DataFrame({'Comments':comments,'Upvote':upvote,'Time':time})
df
# Out:
#                                              Comments Upvote  \
# 0   Explain the stuff you learn to others. Works m...   1.4K
# 1   I would love to learn more about Elon: mind, b...    856
# 2   Elon needs his own school where he basically m...    108
# 3   He said “Assign meaning”, that’s very deep phi...    376
# 4   Assigning a reason for learning, what is happe...    258
# 5   Emotions. You remember more when there's an em...    179
# 6   This can’t be more true. Growing up from K-12 ...    175
# 7   "Your brain will tend to forget most of the th...     45
# 8   Mnemonic tricks is an old school way to rememb...      3
# 9   Memories are best formed by negative experienc...     27
# 10  My brain is super skilled at forgetting everyt...      7
# 11  This makes so much sense. Most of my childhood...      2
# 12             Words from him is a treasure in itself      1
# 13  Elon answering that question while wearing tha...     31
# ...

# %% [markdown]
# ### 9. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# let first connect to the driver 
driver = webdriver.Chrome(r"C:\Users\ASUS\Downloads\chromedriver_win32.zip\chormedriver.exe")
#Let's maximize the automated chrome window
driver.maximize_window()
#Opening up amazon.com website on automated chrome window
url = 'https://www.hostelworld.com/'
driver.get(url)

# %%
location_tag = driver.find_element(By.XPATH,'//input[@class="search-input"]')
location_tag.send_keys('London')

location = driver.find_element(By.TAG_NAME,'li')
letsgo = driver.find_element(By.XPATH,'//button[@class="button primary large"]')
letsgo.click()

# %%
fac=[]
facc = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
for i in facc:
    fac.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22548\2570860962.py in <module>
#       1 fac=[]
# ----> 2 facc = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
#       3 for i in facc:
#       4     fac.append(i.text)
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#     859         # Return empty list if driver returns null
#     860         # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 861         return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#     862
#     863     @property
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22548\1627338876.py in <module>
#       6 wait = WebDriverWait(driver, 10)
#       7
# ----> 8 facc = wait.until(EC.presence_of_all_elements_located((By.XPATH, '//div[@class="facilities-label facilities"]')))
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      84         while True:
#      85             try:
# ---> 86                 value = method(self._driver)
#      87                 if value:
#      88                     return value
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\support\expected_conditions.py in _predicate(driver)
#     172
#     173     def _predicate(driver):
# --> 174         return driver.find_elements(*locator)
#     175
#     176     return _predicate
#
# ...

# %%
total=[]
to = driver.find_elements(By.XPATH,'//div[@class="keyword"]')
for i in to:
    total.append(i.text)
total
# Out:
# ['Very Good',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Good',
#  'Fabulous',
#  'Very Good',
#  'Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Rating',
#  'Very Good',
#  'Rating',
#  'Fabulous',
#  'Good',
#  'Good',
#  'Superb',
#  'Rating',
#  'Very Good',
#  'No Rating',
#  'Rating',
#  'Rating']

# %%
name=[]
hostel = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in hostel:
    name.append(i.text)
name
# Out:
# ["St Christopher's Village",
#  'Hostel One Notting Hill',
#  'Generator London',
#  'Safestay London Elephant & Castle',
#  'Urbany Hostel London',
#  'Smart Hyde Park Inn Hostel',
#  'Safestay London Kensington Holland Park',
#  "St Christopher's Camden",
#  "St Christopher's Hammersmith",
#  'Queen Elizabeth Chelsea',
#  'Saint James Backpackers',
#  "St Christopher's Greenwich",
#  "St Christopher's Shepherds Bush",
#  'Bell House Hostel',
#  'PubLove @ The White Ferry, Victoria',
#  'Hostelle London',
#  'Kensal Green Backpackers',
#  'PubLove @ The Crown, Battersea',
#  'London Waterloo Hostel',
#  'Elmwood Hotel',
#  'PubLove @ The Exmouth Arms, Euston',
#  'PubLove @ The Green Man, Paddington',
#  'London House Hotel',
#  'Colliers Hotel',
#  'Hanover Hotel',
#  'Budget London Apartments',
#  'The London Home Hostel']

# %%
dis=[]
distance = driver.find_elements(By.CLASS_NAME,'description')
for i in distance:
    dis.append(i.text)
    
rating =[]
rate = driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
for i in rate :
    rating.append(i.text)
    
reviews =[]
review = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
for i in review:
    reviews.append(i.text)
reviews
# Out:
# ['12048 Total Reviews',
#  '1952 Total Reviews',
#  '7429 Total Reviews',
#  '4897 Total Reviews',
#  '724 Total Reviews',
#  '6562 Total Reviews',
#  '1480 Total Reviews',
#  '4013 Total Reviews',
#  '4220 Total Reviews',
#  '3445 Total Reviews',
#  '1873 Total Reviews',
#  '3329 Total Reviews',
#  '764 Total Reviews',
#  '50 Total Reviews',
#  '324 Total Reviews',
#  '7 Total Reviews',
#  '3706 Total Reviews',
#  '298 Total Reviews',
#  '2528 Total Reviews',
#  '126 Total Reviews',
#  '1072 Total Reviews',
#  '443 Total Reviews',
#  '1383 Total Reviews',
#  '9 Total Reviews',
#  '46 Total Reviews',
#  '357 Total Reviews',
#  '262 Total Reviews']

# %%
len(dis)
# Out:
# 27

# %%
privates =[]
private= driver.find_elements(By.XPATH,'//div[@class="accommodation-price unavailable"]')
for i in private:
    privates.append(i.text)
privates[0:33:2]
# Out:
# ['No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Dorms Available',
#  'No Privates Available']

# %%
price = []
pri= driver.find_elements(By.XPATH,'//a[@class="prices"]')
for i in pri:
    price.append(i.text)
price
# Out:
# ['From Rs3448',
#  'No Privates Available\nDorms From\nRs3831.09 Rs3448',
#  'Privates From\nRs20898\nDorms From\nRs6658',
#  'Privates From\nRs22100\nDorms From\nRs5023',
#  'No Privates Available\nDorms From\nRs4463',
#  'No Privates Available\nDorms From\nRs5819',
#  'No Privates Available\nDorms From\nRs3425.27 Rs3083',
#  'No Privates Available\nDorms From\nRs4043',
#  'No Privates Available\nDorms From\nRs4375.84 Rs3938',
#  'No Privates Available\nDorms From\nRs3196.61 Rs2877',
#  'No Privates Available\nDorms From\nRs3388',
#  'No Privates Available\nDorms From\nRs6201',
#  'No Privates Available\nDorms From\nRs3083.04 Rs2775',
#  'No Privates Available\nDorms From\nRs3959.8 Rs3564',
#  'No Privates Available\nDorms From\nRs4661',
#  'No Privates Available\nDorms From\nRs7121',
#  'No Privates Available\nDorms From\nRs7734',
#  'No Privates Available\nDorms From\nRs3066',
#  'No Privates Available\nDorms From\nRs4940',
#  'No Privates Available\nDorms From\nRs4231',
# ...

# %%
pvt_prices = []
for i in driver.find_elements(By.XPATH, "//div[@class='current']  //div[@class='accommodation-price unavailable']"):
    if i.text.startswith("₹"):
        pvt_prices.append(i.text)
    else:
        pvt_prices.append(f"Second class: {i.text}")

# %%
pvt_prices
# Out:
# []

# %%
des=[]
dis = driver.find_elements(By.XPATH,'//span[@class="description"]')
for i in dis:
    des.append(i.text)
des
# Out:
# ['Hostel - 1.8km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 3km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 5km from city centre',
#  'Hostel - 5.8km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hostel - 7.5km from city centre',
#  'Hostel - 5.7km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 7.6km from city centre',
#  'Hostel - 7km from city centre',
#  'Hostel - 4.2km from city centre',
#  'Hostel - 2.4km from city centre',
#  'Hostel - 5.1km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 4.7km from city centre',
#  'Hostel - 0.7km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hostel - 3.4km from city centre',
#  'Hostel - 4.3km from city centre',
#  'Hotel - 5.3km from city centre',
#  'Hotel - 2.1km from city centre',
#  'Hotel - 2.1km from city centre',
#  'Apartment - 8.2km from city centre',
# ...

# %%
# creating empty list & find required data
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description = []
url = []

# %%
# scraping the required informations
for i in driver.find_elements(By.XPATH, "//div[@class='pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(3)
    
    # scraping hostel name
    try:
        name = driver.find_elements(By.XPATH, "//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        
    # scraping distance from city centre
    try:
        dist = driver.find_elements(By.XPATH, "//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements(By.XPATH, "//div[@class='prices-col']"):
        # scraping privates from price
        try:
            pvt_price = i.find_element(By.XPATH, "./a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
   
        # scraping dorms from price
        try:
            dorms = i.find_element(By.XPATH, "./a[@class='prices']//div[2]/div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            
    # scraping facilities
    try:
        fac1 = driver.find_elements(By.XPATH, "//div[@class='has-wifi']")
        fac2 = driver.find_elements(By.XPATH, "//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text)
    except NoSuchElementException:
        facilities.append('-')
     
            
    # fetching url of each hostel
    p_url = driver.find_elements(By.XPATH, "//div[@class='prices-col']//a[2]")
    for i in p_url:
        url.append(i.get_attribute("href"))
        
for i in url:
    driver.get(i)
    time.sleep(3)
    
    # scraping ratings
    try:
        rat = driver.find_element(By.XPATH, "//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
    # scraping total review
    try:
        rws = driver.find_element(By.XPATH, "//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        
    # fetching overall review
    try:
        overall = driver.find_element(By.XPATH, "//div[@class='keyword']//span")
        over_all.append(overall.text)
    except NoSuchElementException:
        over_all.append('-')
        
    # fetching property description
    try:
        disc = driver.find_element(By.XPATH, "//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        description.append('-')
    
    # click on show more button for description
    try:
        show_more = driver.find_element(By.XPATH, "//a[@class='toggle-content']")
        show_more.click()
        time.sleep(4)
    except NoSuchElementException:
        pass

# %%
# creating DataFrame
Hostel = pd.DataFrame({})
Hostel['Hostel Name'] = hostel_name
Hostel['Distance from City Centre'] = distance
Hostel['Ratings'] = rating
Hostel['Total Reviews'] = reviews
Hostel['Overall Reviews'] = over_all
Hostel['Privates from Price'] = pvt_prices
Hostel['Dorms from Price'] = dorms_price
Hostel['Facilities'] = facilities[:74]
Hostel['Description'] = description
Hostel
# Out:
# Empty DataFrame
# Columns: [Hostel Name, Distance from City Centre, Ratings, Total Reviews, Overall Reviews, Privates from Price, Dorms from Price, Facilities, Description]
# Index: []

# %%
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_30524\803662830.py", line 91
#     time.sleep(4)
#                  ^
# SyntaxError: unexpected EOF while parsing
